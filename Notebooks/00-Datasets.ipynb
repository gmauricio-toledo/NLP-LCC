# %% [markdown]
# <a href="https://colab.research.google.com/github/gmauricio-toledo/NLP-LCC/blob/main/Notebooks/00-Datasets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1>Exploración de corpus</h1>
#
# Los datasets de texto los leeremos usualmente en archivos `csv`, archivos de texto en general, o archivos `PDF`.
#
# A continuación comenzamos el análisis exploratorio de algunos corpus.

# %% [markdown]
# Leer desde Google Drive

# %%
# !gdown 18kGdlhOiQNS61wUK7uPbdquKL3XJrgzf
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=18kGdlhOiQNS61wUK7uPbdquKL3XJrgzf
# To: /content/IMDB.csv
# 100% 66.2M/66.2M [00:01<00:00, 48.3MB/s]

# %% [markdown]
# Leemos el archivo `csv` con [pandas](https://pandas.pydata.org/docs/user_guide/index.html) en un [dataframe](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.html#pandas.DataFrame)

# %%
import pandas as pd

df = pd.read_csv('IMDB.csv')
df
# Out:
#                                                   review sentiment
# 0      One of the other reviewers has mentioned that ...  positive
# 1      A wonderful little production. <br /><br />The...  positive
# 2      I thought this was a wonderful way to spend ti...  positive
# 3      Basically there's a family where a little boy ...  negative
# 4      Petter Mattei's "Love in the Time of Money" is...  positive
# ...                                                  ...       ...
# 49995  I thought this movie did a down right good job...  positive
# 49996  Bad plot, bad dialogue, bad acting, idiotic di...  negative
# 49997  I am a Catholic taught in parochial elementary...  negative
# 49998  I'm going to have to disagree with the previou...  negative
# 49999  No one expects the Star Trek movies to be high...  negative
#
# [50000 rows x 2 columns]

# %% [markdown]
# Podemos ver que es un dataset etiquetado

# %%
# !gdown 1b0cmrHesxIXzZhxAEqRizdL8zOFXyK9V
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1b0cmrHesxIXzZhxAEqRizdL8zOFXyK9V
# To: /content/topics_unlabeled.csv
# 100% 6.89M/6.89M [00:00<00:00, 34.3MB/s]

# %%
import pandas as pd

topics_df = pd.read_csv('topics_unlabeled.csv')
topics_df
# Out:
#                                                    text
# 0     Inventory Control Associate - 1st Shift  Overv...
# 1     i was not expecting the highest calibre of fil...
# 2     next generation cellular networks will have to...
# 3     humans should understand and produce new utter...
# 4     Drone-Car Engineer  Company DescriptionLorenz ...
# ...                                                 ...
# 4183  Associate Engineer -- Distributed Energy Resou...
# 4184  machine learning algorithms considering predic...
# 4185  director vincenzo natali s cypher is a complex...
# 4186  Healthcare Call Center  Aston Carter has an EX...
# 4187  this paper covers the number of approaches tha...
#
# [4188 rows x 1 columns]

# %% [markdown]
# El anterior es un corpus no etiquetado

# %%
from numpy.random import rand
import numpy as np

random_idxs = np.random.choice(len(topics_df), 3)

for k in random_idxs:
    print(topics_df.iloc[k]['text'])
    print(50*"=")
# Out:
# Obesssive Compulsive Disorder (not to be confused with Obsessive Compulsive
# _Personality_ Disorder !) is an acute anxiety disorder characterized by
# either obsessions (persistent intrusive thoughts that cause anxiety when
# not entertained), or compulsions (repetitive, ritualistic actions that
# similarly cause intense psychological discomfort when resisted).
#
# OCD is often associated with certain forms of depression.
#
# Examples of obsessive thoughts are repeated impulses to kill a loved
# one (though not accompanied by anger), or a religious person having
# recurrent blasphemous thoughts.  Generally, the individual attempts to ignore
# or suppress the intrusive thoughts by engaging in other activities.
# The individual realizes that the thoughts originate from the own mind, rather
# than being from an external source.
#
# Examples of compulsive actions are constant repetitive hand washing,
# or other activity that is not realistically related to alleviating a
# ...
